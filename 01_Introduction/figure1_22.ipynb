# %% [markdown]
# # M_files_chap01/figure1_22.m
#
# Python 3 implementation of the MATLAB code from the book:
#
# <b>DAFX - Digital Audio Effects</b> <br>
# Edited by Udo Zölzer<br>
# ISBN: 978-0-470-66599-2<br>
# Second Edition, John Wiley & Sons, 2011<br>
# Matlab files source: http://ant-s4.unibw-hamburg.de/dafx/DAFX_Book_Page_2nd_edition/matlab.html

# %%
import matplotlib.pyplot as plt
from scipy import signal
from scipy.fftpack import fft
from scipy.io import wavfile
import IPython
from IPython.display import Audio
from waterfspec import waterfspec
# %matplotlib inline
plt.style.use('ggplot')

# %%
AudioFileName = "ton2.wav"
# Load audio File
Fs, data = wavfile.read(AudioFileName)
IPython.display.Audio(AudioFileName)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Ploting Signals
plt.rcParams['figure.figsize'] = (8, 3)# figure size
data = data*1.0/(2.**15) # Scale the signal in [-1, 1] for 16 bits input
plt.plot(data)
plt.title('Signal x(n)')
plt.ylabel('x(n)')
plt.xlabel('n')
plt.xlim([0,len(data)]);

# %%
#waterfall spectrum plot
plt.rcParams['figure.figsize'] = (10, 5)# figure size
waterfspec(data,256,256,512,Fs,20,-100)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-9f14d5f4b807> in <module>()
#       1 #waterfall spectrum plot
#       2 plt.rcParams['figure.figsize'] = (10, 5)# figure size
# ----> 3 waterfspec(data,256,256,512,Fs,20,-100)
#
# /home/joser/Dropbox/Investigacion/Publicaciones/GitHub/PyDAFX/01_Introduction/waterfspec.pyc in waterfspec(data, start, steps, N, fS, clippingpoint, baseplane)
#      70     y = range(len(x/2))
#      71     poly.set_alpha(1)
# ---> 72     ax.add_collection3d(poly, zs=y, zdir='y')
#      73     ax.set_title('Waterfall Representation of Short-time FFTs')
#      74     ax.set_xlabel('f in Hz')
#
# /usr/local/lib/python2.7/dist-packages/mpl_toolkits/mplot3d/axes3d.pyc in add_collection3d(self, col, zs, zdir)
#    2292         #       abstract class to test for and exclude?
#    2293         if type(col) is mcoll.PolyCollection:
# ...

# %%
N = 512
plt.rcParams['figure.figsize'] = (10, 4)# figure size
Pxx, freqs, bins, im = plt.specgram(data, NFFT=N, Fs=Fs,window = signal.blackman(N),noverlap = 0)
plt.title('specgram')
plt.ylabel('Freq in Hz')
plt.axis('tight');
